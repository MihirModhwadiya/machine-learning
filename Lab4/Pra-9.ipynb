# %% [markdown]
# ### Pra-9). Write a Pandas program to create a plot of Open, High, Low, Close, Adjusted Closing prices and Volume of given company between two specific dates.

# %%
import pandas as pd
import matplotlib.pyplot as plt
ds = pd.read_csv("../Lab3/Pra_8_data_sets/Netflix_stock_history.csv")

ds.set_index('Date', inplace=True)

start = '2021-09-20'
end = '2021-09-24'

ploat = ds.loc[start:end]

plt.figure(figsize=(12, 8))

plt.plot(ploat.index, ploat['Open'], label='Opening Price', color="blue")
plt.plot(ploat.index, ploat['High'], label='High Price', color="green")
plt.plot(ploat.index, ploat['Low'], label='Low Price', color="gray")
plt.plot(ploat.index, ploat['Close'], label='Closing Price', color="red")
# plt.plot(ploat.index, ploat['Volume'], label='Volume Price', color="orange")

plt.xlabel('Date')

# plt.plot(ploat.index, ploat['Volume'], label='Volume Price', color="orange")
plt.ylabel('Price')
plt.title('Netflix Stock Price')
plt.legend()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the CSV file into a Pandas DataFrame
df = pd.read_csv('../Lab3/Pra_8_data_sets/Netflix_stock_history.csv')

# Convert the 'Date' column to datetime if it's not already in datetime format
df['Date'] = pd.to_datetime(df['Date'])

# Set the 'Date' column as the index
df.set_index('Date', inplace=True)

# Specify the date range you want to plot
start_date = '2021-09-14'
end_date = '2021-09-24'

# Slice the DataFrame to select data within the specified date range
df = df.loc[start_date:end_date]

# Create a plot of Open, High, Low, Close, and Adjusted Closing prices
plt.figure(figsize=(12, 6))
plt.plot(df.index, df['Open'], label='Open', linewidth=2)
plt.plot(df.index, df['High'], label='High', linewidth=2)
plt.plot(df.index, df['Low'], label='Low', linewidth=2)
plt.plot(df.index, df['Close'], label='Close', linewidth=2)
# plt.plot(df.index, df['Adj Close'], label='Adjusted Close', linewidth=2)

# Create a plot for Volume in a separate subplot
plt.figure(figsize=(12, 3))
plt.plot(df.index, df['Volume'], label='Volume', linewidth=2, color='blue')

# Customize the plot
plt.title('Stock Prices and Volume')
plt.xlabel('Date')
plt.ylabel('Price/Volume')
plt.grid(True)
plt.legend()

# Show the plots
plt.tight_layout()
plt.show()
